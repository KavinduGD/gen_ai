# %% [markdown]
# # Model use with APIS

# %% [markdown]
# ## 1. Using Rest APIs

# %% [markdown]
# ### 1.1 OpenAI Rest API

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
chat_gpt_api_key = os.getenv('OPENAI_API_KEY')

if not chat_gpt_api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")

# %%
import requests

headers = {"Authorization": f"Bearer {chat_gpt_api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'gpt-5-nano',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json().get('choices', [{}])[0].get('message', {}).get('content', '')
# Out:
# 'Fun fact: A single cloud can weigh more than a million pounds (about 450,000 kilograms) because of all the water droplets it contains.'

# %% [markdown]
# ### 1.2 Gemini Rest API

# %%
gemini_api_key = os.getenv('GOOGLE_API_KEY')
headers = {"Authorization": f"Bearer {gemini_api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gemini-3.1-flash-lite-preview",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

# %%
response = requests.post(
    "https://generativelanguage.googleapis.com/v1beta/openai/chat/completions",
    headers=headers,
    json=payload
)

response.json().get('choices', [{}])[0].get('message', {}).get('content', '')
# Out:
# 'Did you know that **sea otters hold hands when they sleep?**\n\nThey do this to keep from drifting apart in the water while they nap. They often form "rafts" by linking together, sometimes even wrapping themselves in giant kelp to stay anchored to one spot!'

# %% [markdown]
# # 2. Using Openai Python Library

# %% [markdown]
# ### 2.1. OpenAI Python Library with ChatGPT Models

# %%
# Create OpenAI client

from openai import OpenAI
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Fun fact: A single fluffy cloud can weigh more than a million pounds. Clouds look light, but the water they contain adds up to a massive mass.'

# %% [markdown]
# ### 2.2. OpenAI Python Library with Gemini Models

# %%
from openai import OpenAI
load_dotenv(override=True)

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")

gemini=OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response = gemini.chat.completions.create(model="gemini-3.1-flash-lite-preview", messages=[{"role": "user", "content": "Tell me a fun fact"}])
response.choices[0].message.content
# Out:
# 'Sea otters hold hands when they sleep so they don’t drift away from each other. They often form groups called a "raft" and will sometimes wrap themselves in giant kelp to act as an anchor while they snooze!'
